# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib notebook

# %%
os.getcwd()
# Out:
# '/Users/cyang/coding/projects/dnpsoup0/py_scripts/case_studies/examples/TOTAPOL'

# %%
result_folder = '../../../../results/'

# %%
result_filename = 'TOTAPOL_eeH_cw_400MHz_eigenvals_output.log'
result_path = os.path.join(result_folder, result_filename)
os.path.exists(result_path)
# Out:
# True

# %%
df_eigenvals = pd.read_csv(result_path, delimiter=',', skiprows=1, header=None)
df_eigenvals.head()
# Out:
#               0             1             2             3             4  \
# 0  0.000000e+00 -9.420352e+10 -9.406133e+10 -1.122811e+08 -3.206043e+07
# 1  9.979023e-09 -9.420352e+10 -9.406133e+10 -1.122301e+08 -3.211143e+07
# 2  1.995805e-08 -9.420352e+10 -9.406133e+10 -1.121791e+08 -3.216246e+07
# 3  2.993707e-08 -9.420352e+10 -9.406133e+10 -1.121280e+08 -3.221350e+07
# 4  3.991609e-08 -9.420352e+10 -9.406133e+10 -1.120770e+08 -3.226456e+07
#
#               5             6             7             8
# 0  2.991912e+07  1.110117e+08  9.406259e+10  9.420567e+10
# 1  2.997013e+07  1.109607e+08  9.406259e+10  9.420567e+10
# 2  3.002115e+07  1.109096e+08  9.406259e+10  9.420567e+10
# 3  3.007219e+07  1.108586e+08  9.406259e+10  9.420567e+10
# 4  3.012325e+07  1.108075e+08  9.406259e+10  9.420567e+10

# %%
fig, axes = plt.subplots(1, 1, figsize=(6,3))
df_eigenvals.plot(x=0, y=[3, 4, 5, 6], ax=axes)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.4444603242996">
