# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
os.getcwd()
# Out:
# '/home/chen/coding/projects/dnpsoup0/py_scripts/case_studies/examples/TOPDNP'

# %%
os.listdir('../../../../results/TOPDNP')
# Out:
# ['eHH_pSE_xband_4MHz_zcw34_em_fp.result']

# %% [markdown]
# ## Pulsed Solid Effect

# %% [markdown]
# #### Field Profile

# %%
datadir = '../../../../results/TOPDNP'

# %%
filename = 'eHH_pSE_xband_4MHz_zcw34_em_fp.result'

# %%
filepath = os.path.join(datadir, filename)
df = pd.read_csv(filepath, skiprows=1, header=None)
df.head()
# Out:
#             0         1
# 0  9780000000  1.265347
# 1  9780500000  1.287417
# 2  9781000000  1.316289
# 3  9781500000  1.352316
# 4  9782000000  1.394909

# %%
fig = plt.figure(figsize=(8, 4))
plt.plot(df[0]/1e9, df[1], 'bo-', markerfacecolor='none')
plt.xlabel('Gyrotron Frequency (GHz)')
plt.ylabel('Enhancement')
plt.title('Pulsed Solid Effect')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
