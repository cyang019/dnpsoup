# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.pylab as pl

# %%
# %matplotlib notebook

# %%
os.getcwd()
# Out:
# '/Users/cyang/coding/projects/dnpsoup0/py_scripts/case_studies/examples'

# %%
#os.listdir('../../../results/v2/ISE_SSE')

# %%
data_dir = '../../../results/v2/ISE_SSE'

# %% [markdown]
# ### Scan Loop

# %%
filename = 'eH_gtensor_trityl_a0b90b0_wband_oct34_scan1d_loop_1_to_10k.result'
filepath = os.path.join(data_dir, filename)
df = pd.read_csv(filepath, skiprows=2, header=None)
fig = plt.figure()
plt.plot(df[0], df[1], 'b-o', markerfacecolor='none')
plt.xlabel('Count of Repetition (A.U.)')
plt.ylabel('Enhancement (A.U.)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# ### Field Profile

# %%
filename1 = 'eH_gtensor_trityl_a0b40g0_wband_loop4k_chirp_300MHz_oct89_em_fp_step0p01.result'
filename2 = 'eH_gtensor_trityl_a0b40g0_wband_loop4k_chirp_neg300MHz_oct89_em_fp_step0p01.result'
filepath1 = os.path.join(data_dir, filename1)
filepath2 = os.path.join(data_dir, filename2)
df1 = pd.read_csv(filepath1, skiprows=2, header=None)
df2 = pd.read_csv(filepath2, skiprows=2, header=None)
fig = plt.figure()
plt.plot(df1[0]/1e9, df1[1], 'r-o', markerfacecolor='none')
plt.plot(df2[0]/1e9, df2[1], 'b-s', markerfacecolor='none')
plt.xlabel('Gyrotron Frequency (GHz)')
plt.ylabel('Enhancement (A.U.)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# ### Investigate Euler Angle

# %%
labels = [
    'a0b0g0',
    'a45b0g0',
    'a90b0g0',
    'a120b0g0',
    'a160b0g0'
#     'a0b90g0'
]

# %%
filenames = [
    'eH_gtensor_trityl_a0b90b0_wband_loop4k_xtal_em_fp.result',
    'eH_gtensor_trityl_a0b90b0_wband_loop4k_xtal_a45b0g0_em_fp.result',
    'eH_gtensor_trityl_a0b90b0_wband_loop4k_xtal_a90b0g0_em_fp.result',
    'eH_gtensor_trityl_a0b90b0_wband_loop4k_xtal_a120b0g0_em_fp.result',
    'eH_gtensor_trityl_a0b90b0_wband_loop4k_xtal_a160b0g0_em_fp.result'
#     'eH_gtensor_trityl_a0b90b0_wband_loop4k_xtal_a0b90g0_em_fp.result'
]

# %%
n = len(filenames)
colors = plt.cm.rainbow(np.linspace(0.1,0.9,n))

dfs = []
for filename in filenames:
    filepath = os.path.join(data_dir, filename)
    df_temp = pd.read_csv(filepath, skiprows=2, header=None)
    dfs.append(df_temp)
df_temp = None

fig = plt.figure(figsize=(10, 6))
for df, c, label in zip(dfs, colors, labels):
    plt.plot(df[0]/1e9, df[1], linestyle='-', color=c, markerfacecolor='none', label=label)
plt.xlabel('Gyrotron Frequency (GHz)')
plt.ylabel('Enhancement')

plt.title('TOP-DNP Field Profile')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.4444709206812">

# %%
labels = [
    'a0b0g0',
    'a0b45g0',
    'a0b60g0',
    'a0b90g0'
]

# %%
filenames = [
    'eH_gtensor_trityl_a0b90b0_wband_loop4k_xtal_em_fp.result',
    'eH_gtensor_trityl_a0b90b0_wband_loop4k_xtal_a0b45g0_em_fp.result',
    'eH_gtensor_trityl_a0b90b0_wband_loop4k_xtal_a0b60g0_em_fp.result',
    'eH_gtensor_trityl_a0b90b0_wband_loop4k_xtal_a0b90g0_em_fp.result',
#     'eH_gtensor_trityl_a0b90b0_wband_loop4k_xtal_a0b90g0_em_fp.result'
]

# %%
n = len(filenames)
colors = plt.cm.rainbow(np.linspace(0.1,0.9,n))

dfs = []
for filename in filenames:
    filepath = os.path.join(data_dir, filename)
    df_temp = pd.read_csv(filepath, skiprows=2, header=None)
    dfs.append(df_temp)
df_temp = None

fig = plt.figure(figsize=(10, 6))
for df, c, label in zip(dfs, colors, labels):
    plt.plot(df[0]/1e9, df[1], linestyle='-', color=c, markerfacecolor='none', label=label)
plt.xlabel('Gyrotron Frequency (GHz)')
plt.ylabel('Enhancement')

plt.title('TOP-DNP Field Profile')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.4444709206812">
