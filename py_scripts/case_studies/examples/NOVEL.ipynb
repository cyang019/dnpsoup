# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.pylab as pl

# %%
# %matplotlib notebook

# %%
os.getcwd()
# Out:
# '/Users/cyang/coding/projects/dnpsoup0/py_scripts/case_studies/examples'

# %%
os.listdir('../../../results/v2/NOVEL/')
# Out:
# ['eH_NOVEL_xband_scan_loop.result',
#  'eH_NOVEL_xband_scan_d.result',
#  'eH_NOVEL_xband_loop6k_fp.result',
#  'eH_NOVEL_xband_loop10k_scan_gammaB1.result',
#  'e_g_BDPA_300us_5us_H_3s_200us_NOVEL_xband_field_fp.result',
#  'eH_NOVEL_xband_loop7k_fp.result',
#  'eH_NOVEL_xband_loop100k_fp.result',
#  'eH_NOVEL_xband_scan_pmix.result']

# %%
datadir = '../../../results/v2/NOVEL'

# %% [markdown]
# ### Scan Mixing Time

# %%
filename = 'eH_NOVEL_xband_scan_pmix.result'
filepath = os.path.join(datadir, filename)
df = pd.read_csv(filepath, skiprows=2, header=None)
fig = plt.figure()
plt.plot(df[0], df[1], 'b-x')
plt.xlabel('Mixing Time (ns)')
plt.ylabel('Enhancement (A.U.)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# ### Scan Delay

# %%
filename = 'eH_NOVEL_xband_scan_d.result'
filepath = os.path.join(datadir, filename)
df = pd.read_csv(filepath, skiprows=2, header=None)
fig = plt.figure()
plt.plot(df[0]/1e3, df[1], 'b-o', markerfacecolor='none')
plt.xlabel('Delay ($\mu$s)')
plt.ylabel('Enhancement (A.U.)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# ### Scan Repetition Count

# %%
filename = 'eH_NOVEL_xband_scan_loop.result'
filepath = os.path.join(datadir, filename)
df = pd.read_csv(filepath, skiprows=2, header=None)
fig = plt.figure()
plt.plot(df[0], df[1], 'b-x')
plt.xlabel('Loop Count (A.U.)')
plt.ylabel('Enhancement (A.U.)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# ### Scan $\omega_{1s}$

# %%
filename = 'eH_NOVEL_xband_loop10k_scan_gammaB1.result'
filepath = os.path.join(datadir, filename)
df = pd.read_csv(filepath, skiprows=2, header=None)
fig = plt.figure()
plt.plot(df[0]/1e6, df[1], 'b-x')
plt.xlabel('$\omega_{1s}$ (MHz)')
plt.ylabel('Enhancement (A.U.)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# ### Field Profile

# %%
filename = 'eH_NOVEL_xband_loop100k_fp.result'
filepath = os.path.join(datadir, filename)
df = pd.read_csv(filepath, skiprows=2, header=None)
fig = plt.figure()
plt.plot(df[0], df[1], 'b-+')
plt.xlabel('Magnetic Field (T)')
plt.ylabel('Enhancement (A.U.)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
