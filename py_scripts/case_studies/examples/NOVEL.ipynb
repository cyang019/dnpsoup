# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.pylab as pl

# %%
# %matplotlib notebook

# %%
os.getcwd()
# Out:
# '/Users/cyang/coding/projects/dnpsoup0/py_scripts/case_studies/examples'

# %%
os.listdir('../../../results/v2/NOVEL/')
# Out:
# ['eH_NOVEL_xband_scan_loop.result',
#  'eH_NOVEL_xband_scan_d.result',
#  'eH_NOVEL_xband_loop6k_fp.result',
#  'e_g_BDPA_300us_5us_H_3s_200us_NOVEL_xband_field_fp.result',
#  'eH_NOVEL_xband_loop7k_fp.result',
#  'eH_NOVEL_xband_scan_pmix.result']

# %%
datadir = '../../../results/v2/NOVEL'

# %%
filenames = [
    'eH_NOVEL_xband_loop6k_fp.result',
    'eH_NOVEL_xband_loop7k_fp.result',
    'eH_NOVEL_xband_loop100k_fp.result'
]
n = len(filenames)
colors = plt.cm.rainbow(np.linspace(0.1,0.9,n))
labels = [
    'loop 6k',
    'loop 7k',
    'loop 100k'
]

dfs = []
for filename in filenames:
    filepath = os.path.join(datadir, filename)
    df_temp = pd.read_csv(filepath, skiprows=2, header=None)
    dfs.append(df_temp)
df_temp = None

fig = plt.figure(figsize=(10, 6))
for df, c, label in zip(dfs, colors, labels):
    plt.plot(df[0], df[1], linestyle='-', color=c, markerfacecolor='none', label=label)
plt.xlabel('Magnetic Field (T)')
plt.ylabel('Enhancement')
plt.title('NOVEL Field Profile')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.4444709206812">
